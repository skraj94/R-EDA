# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup as soup

url = 'https://www.google.com'
response = requests.get(url)
page_html = response.content
#print page_html

page_soup=soup(page_html,"html.parser")
print (page_soup)
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
from selenium import webdriver

import time

driver = webdriver.Chrome(executable_path='C:/Users/SKR/Anaconda3/Lib/chromedriver.exe')

driver.get('https://pitchfork.com/reviews/tracks/otha-one-of-the-girls/')

driver.execute_script('window.scrollTo(1, 500);')

#now wait let load the comments
time.sleep(5)

driver.execute_script('window.scrollTo(1, 3000);')



comment_div=driver.find_element_by_xpath('//*[@id="contents"]')
comments=comment_div.find_elements_by_xpath('//*[@id="content-text"]')
for comment in comments:
    print(comment.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-5-2e966017efa4> in <module>
#      16
#      17
# ---> 18 comment_div=driver.find_element_by_xpath('//*[@id="contents"]')
#      19 comments=comment_div.find_elements_by_xpath('//*[@id="content-text"]')
#      20 for comment in comments:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
import justext

response = requests.get("http://bbc.com/")
paragraphs = justext.justext(response.content, justext.get_stoplist("English"))
for paragraph in paragraphs:
    if len(paragraph) > 10:
        print (paragraph.text)
# Out:
# Accessibility links
# Skip to content
# Accessibility Help
# BBC Account
# Notifications
# Search the BBC
# BBC Homepage
# China separating Muslim children from families
# Thousands of ethnic minority Muslim children undergo "cultural re-engineering" in giant boarding schools.
# China separating Muslim children from families
# What do Indians want from the latest Budget?
# What do Indians want from the latest Budget?
# Why are menstruating women removing their wombs?
# Why are menstruating women removing their wombs?
# Nadal beats irate Kyrgios in thriller
# Nadal beats irate Kyrgios in thriller
# Missing husband found on TikTok app in India
# Missing husband found on TikTok app in India
# Trump leads Salute to America celebration
# President Donald Trump has hailed the "brave men and women" of the US military at 4 July event.
# US & Canada
# Trump leads Salute to America celebration
# California hit by biggest earthquake in 20 years
# ...

# %%
help(driver.execute_script)
# Out:
# Help on method execute_script in module selenium.webdriver.remote.webdriver:
#
# execute_script(script, *args) method of selenium.webdriver.chrome.webdriver.WebDriver instance
#     Synchronously Executes JavaScript in the current window/frame.
#
#     :Args:
#      - script: The JavaScript to execute.
#      - \*args: Any applicable arguments for your JavaScript.
#
#     :Usage:
#         driver.execute_script('return document.title;')

# %%
from selenium import webdriver


options = webdriver.ChromeOptions()
options.add_argument("headless")
self.driver = webdriver.Chrome(executable_path='/Users/${userName}/Drivers/chromedriver', chrome_options=options)
# Out:
# <Response [200]>

# %%
##pip install selenium
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument("headless")
driver = webdriver.Chrome(executable_path='C:/Users/SKR/Anaconda3/Lib/chromedriver.exe',chrome_options=options)
driver.get("https://en.wikipedia.org/wiki/Shah_Rukh_Khan")
html = driver.find_element_by_xpath("/html")
print (html.text)
driver.quit()
# Out:
# C:\Users\SKR\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: use options instead of chrome_options
#   """
# Shah Rukh Khan
# From Wikipedia, the free encyclopedia
# Jump to navigation
# Jump to search
# "SRK" redirects here. For other uses, see SRK (disambiguation).
# "Shahrukh Khan" redirects here. For the cricketer, see Shahrukh Khan (cricketer).
# Shah Rukh Khan
# Shah Rukh Khan at an event for Hyundai in 2018
# Born Shahrukh Khan
# 2 November 1965 (age 53)[1]
# New Delhi, Delhi, India[2]
# Residence Mumbai, Maharashtra, India
# Education Hansraj College, Delhi University[3]
# Occupation Actor, film producer, television personality, businessman
# Years active 1988–present
# Works
# Full list
# Spouse(s) Gauri Khan (m. 1991)
# Children 3
# Awards Full list
# Honours Padma Shri (2005)
# Ordre des Arts et des Lettres (2007)
# Légion d'honneur (2014)
# Signature
# ...
