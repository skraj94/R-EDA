# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
forest = pd.read_csv("forestfires.csv")
forest.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
sns.set_style("whitegrid")
sns.boxplot(data=forest, palette="deep")
sns.despine(left=True)

# %%
sns.pairplot(forest)

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize': (8.7,5.27)})
sns.heatmap(forest.corr(),annot = True)
plt.show()

# %% [markdown]
# ### Based on the above correlation values we  can find out the variables which have high corelation between them
# ## Its clear that no single variabke has linear relationship with area affected lets check the combinations of multiple factors,with area

# %%
for i in forest.columns:
    sns.relplot(x=i, y="area", data=forest)

# %%
forest.describe(ax = sns.lineplot(x="timepoint", y="signal",
...                   hue="event", style="event",
...                   markers=True, dashes=False, data=fmri))
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# create seperate databases for pred and target variables

# %%
pred = pd.DataFrame(forest[['FFMC','DMC',"DC",'ISI','temp','RH','wind','rain']],columns=['FFMC','DMC',"DC",'ISI','temp','RH','wind','rain'] )
targ = pd.DataFrame(forest['area'], columns= ['area'])

# %%
# split the datas in to train and test
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(pred, targ, test_size=0.33, random_state=42)

# %%
# fit the lr model
from sklearn import linear_model

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train,y_train)

# %%
# lets predict the model on the train data
predictions = lm.predict(X_train)
#print(predictions)

# %%
# finding the score
lm.score(X_train,y_train)
# Out:
# 0.026760406554061315

# %%
lm.coef_[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ade38787078d> in <module>
# ----> 1 lm.coef_[0]
#
# NameError: name 'lm' is not defined

# %%
#decision tree
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
from sklearn.model_selection import cross_val_score

# %%
 clf_gini = DecisionTreeClassifier(criterion = "gini", 
            random_state = 100,max_depth=3, min_samples_leaf=5)

# %%
X_train, X_test, y_train, y_test = train_test_split(pred, targ, test_size=0.33, random_state=42)

# %%
# clustering algorithm
from sklearn import cluster
import networkx as nx
from collections import defaultdict
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_rand_score

# %%
area1 = pd.DataFrame(forest['area'],columns= 'area')
area1.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-e2ba0677771c> in <module>
# ----> 1 area1 = pd.DataFrame(forest['area'],columns= 'area')
#       2 area1.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     374             elif getattr(data, 'name', None) is not None:
#     375                 mgr = self._init_dict({data.name: data}, index, columns,
# --> 376                                       dtype=dtype)
#     377             else:
#     378                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     430         """
#     431         if columns is not None:
# --> 432             arrays = Series(data, index=columns, dtype=object)
# ...
